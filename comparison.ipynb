# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from geopy.distance import geodesic
from shapely.geometry import LineString
import contextily as ctx

# %%
building_df = pd.read_csv('building_results_unmitigated.csv')
building_df_mitigated = pd.read_csv('building_results_mitigated.csv')

# %%
building_df['mean_downtime'].sum()
# Out:
# 159.86553885091286

# %%
building_df_mitigated['mean_downtime'].sum()
# Out:
# 159.86553885091286

# %%
building_df.inundationDepth
# Out:
# 0      0.257999
# 1      0.897038
# 2      1.019502
# 3      1.217041
# 4      0.217648
# 5     12.447719
# 6      0.147028
# 7      7.589682
# 8      7.683367
# 9     11.909015
# 10    11.329206
# 11     7.079730
# 12     0.000000
# 13    12.388866
# Name: inundationDepth, dtype: float64

# %%
building_df_mitigated.inundationDepth
# Out:
# 0      0.257999
# 1      0.897038
# 2      1.019502
# 3      1.217041
# 4      0.217648
# 5     12.447719
# 6      0.147028
# 7      7.589682
# 8      7.683367
# 9     11.909015
# 10    11.329206
# 11     7.079730
# 12     0.000000
# 13    12.388866
# Name: inundationDepth, dtype: float64

# %%
building_df.LS_0
# Out:
# 7.0000000006

# %%
building_df_mitigated.LS_0
# Out:
# 7.0000000006
